# %% [markdown]
# # PWC361, Task 2 Find Celebrity
# **冯昶 2026-02-16**
#
# Script:

# %%
unit sub MAIN(Str:D $matrix);

use MONKEY-SEE-NO-EVAL;

my @matrix = EVAL $matrix;
put do for (^+@matrix).first({ @matrix[$_].all == 0 and @matrix[*;$_].sum == +@matrix - 1 }) {
    when .defined { $_ }
    default       { -1 }
};

# %% [markdown]
# Try to find a row which is all 0, and the correspoding column with the same index as the row is composed by all 1's but one 0. If such a row is found, print the index of the row, otherwise print -1.
